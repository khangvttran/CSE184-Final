# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

song100 = pd.read_csv("songDataTop100ByYearfixtest.csv")

# %%
sns.violinplot(y = song100['danceability'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['Duration(ms)'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['tempo'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['valence'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['key'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['loudness'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['speechiness'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['acousticness'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['instrumentalness'], x = song100['Year'] , data = song100)

# %%
sns.violinplot(y = song100['liveness'], x = song100['Year'] , data = song100)
