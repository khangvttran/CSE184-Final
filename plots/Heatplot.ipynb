# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

song100 = pd.read_csv("songDataTop100ByYearfixtest.csv")
df = song100[["Duration(ms)", "danceability", "energy", "loudness", "speechiness", "instrumentalness","liveness","valence", "tempo"]]
f,ax = plt.subplots(figsize=(18, 10))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.3f',ax=ax, cmap="Greens")

# %%
sns.scatterplot(x = 'Duration(ms)', y = 'energy', data = song100)

# %%
sns.scatterplot(x = "Duration(ms)", y = 'danceability', data = song100)

# %%
sns.scatterplot(x = "Duration(ms)", y = 'loudness', data = song100)

# %%
sns.scatterplot(x = "Duration(ms)", y = 'valence', data = song100)

# %%
sns.scatterplot(x = "Duration(ms)", y = 'tempo', data = song100)

# %%
sns.scatterplot(x = 'danceability', y = 'energy', data = song100)

# %%
sns.scatterplot(x = 'loudness', y = 'energy', data = song100)

# %%
sns.scatterplot(x = 'energy', y = 'energy', data = song100)
