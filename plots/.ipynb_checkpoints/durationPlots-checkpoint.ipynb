# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
top100 = pd.read_csv('songDataTop100ByYearfixtest.csv')

top100['Duration(ms)'] = top100['Duration(ms)']/60000
top100.rename(columns = {'Duration(ms)':'Duration(min)'}, inplace = True) 
#top100

# %%
singlesDur = sns.lineplot(x = 'Year', y = 'Duration(min)', data = top100, legend = 'full')

singlesDur.plot([2008, 2008], [3.333333, 4.4], linewidth = 1, color = 'green')
singlesDur.text(2008, 4.41, "Spotify Released", horizontalalignment = 'right', size = 'small', color = 'black')

singlesDur.plot([2011, 2011], [3.333333, 4.4], linewidth = 1, color = 'red')
singlesDur.text(2011, 4.41, "Spotify Released (US)", horizontalalignment = 'left', size = 'small', color = 'black')

singlesDur.set_title('Top 100 Songs Durations')
singlesDur

# %%
album200 = pd.read_csv("albumDataTop200ByYear.csv")

album200['album_duration(ms)'] = album200['album_duration(ms)']/60000
album200.rename(columns = {'number_of_tracks':'# of tracks',
                          'album_duration(ms)':'Duration(min)'}, inplace = True)
album200
# Out:
#       Unnamed: 0                      Artist  \
# 0              0                     50 Cent
# 1              1                      Eminem
# 2              2                   Green Day
# 3              3                Mariah Carey
# 4              4              Kelly Clarkson
# 5              5                Gwen Stefani
# 6              6              Destinys Child
# 7              7                          U2
# 8              8                Shania Twain
# 9              9               Rascal Flatts
# 10            10                       Usher
# 11            11                  Toby Keith
# 12            12             Various Artists
# 13            13                    Coldplay
# 14            14                    Lil Jon
# 15            15                    The Game
# 16            16                 The Killers
# 17            17         The Black Eyed Peas
# 18            18                       Ciara
# 19            19                 Ray Charles
# 20            20                  Kanye West
# 21            21                    Ludacris
# 22            22             Gretchen Wilson
# 23            23             Various Artists
# 24            24                  Tim McGraw
# 25            25                    Fantasia
# 26            26                  Snoop Dogg
# 27            27                Jack Johnson
# 28            28                 Keith Urban
# 29            29               George Strait
# ...          ...                         ...
# 2339        2339              Dierks Bentley
# 2340        2340     Five Finger Death Punch
# 2341        2341                        2Pac
# 2342        2342       Red Hot Chili Peppers
# 2343        2343                 Niall Horan
# 2344        2344                 Linkin Park
# 2345        2345                  Macklemore
# 2346        2346                          YG
# 2347        2347              Paul McCartney
# 2348        2348                 Tim McGraw
# 2349        2349                       Logic
# 2350        2350  YoungBoy Never Broke Again
# 2351        2351                       Adele
# 2352        2352                     MercyMe
# 2353        2353                       Ozuna
# 2354        2354                 Kevin Gates
# 2355        2355                 Keith Urban
# 2356        2356                      Future
# 2357        2357                  Anne-Marie
# 2358        2358               Blake Shelton
# 2359        2359                       6LACK
# 2360        2360                       AC/DC
# 2361        2361             Michael Jackson
# 2362        2362                    2 Chainz
# 2363        2363                       Quavo
# 2364        2364                        Cher
# 2365        2365                  BlocBoy JB
# 2366        2366                XXXTENTACION
# 2367        2367               Kenny Chesney
# 2368        2368                  Tory Lanez
#
#                                              Album  Year  Duration(min)  \
# 0                                     The Massacre  2005      77.547617
# 15             18
# 16             11
# 17             15
# 18             13
# 19             12
# 20             21
# 21             16
# 22             10
# 23             27
# 24             16
# 25             13
# 26             20
# 27             14
# 28             13
# 29             50
# ...           ...
# 2339           13
# 2340           16
# 2341           25
# 2342           16
# 2343           13
# 2344           15
# 2345           16
# 2346           15
# 2347           16
# 2348           11
# 2349           14
# 2350           18
# 2351           11
# 2352           13
# 2353           20
# 2354           18
# 2355           13
# 2356           16
# 2357           18
# 2358           21
# 2359           14
# 2360           10
# 2361           30
# 2362           16
# 2363           19
# 2364           10
# 2365           18
# 2366            7
# 2367           29
# 2368           18
#
# [2369 rows x 6 columns]

# %%
albumCt = sns.lineplot(x = 'Year', y = '# of tracks', data = album200)

albumCt.plot([2008, 2008], [13.5, 17], linewidth = 1, color = 'green')
albumCt.text(2008, 17.1, "Spotify Released", horizontalalignment = 'right', size = 'small', color = 'black')

albumCt.plot([2011, 2011], [13.5, 17], linewidth = 1, color = 'red')
albumCt.text(2011, 17.1, "Spotify Released (US)", horizontalalignment = 'left', size = 'small', color = 'black')

albumCt.set_title('Top 200 Albums Track Count')
albumCt

# %%
albumsDur = sns.lineplot(x = 'Year', y = 'Duration(min)', data = album200)

albumsDur.plot([2008, 2008], [52, 64], linewidth = 1, color = 'green')
albumsDur.text(2008, 64.3, "Spotify Release", horizontalalignment='right', size='small', color='black')

albumsDur.plot([2011, 2011], [52, 64], linewidth=1, color = 'red')
albumsDur.text(2011, 64.3, "Spotify Release (US)", horizontalalignment='left', size='small', color='black')

albumsDur.set_title('Top 200 Albums Durations')
albumsDur

# %%
normAlbum200 = album200.copy()
normAlbum200.rename(columns = {'Duration(min)':'Duration'}, inplace = True)

normAlbum200['Duration'] = ((album200['Duration(min)'] - album200['Duration(min)'].mean())/
                                 (album200['Duration(min)'].std()))
normAlbum200['# of tracks'] = ((album200['# of tracks'] - album200['# of tracks'].mean())/
                               (album200['# of tracks'].std()))
normAlbum200
# Out:
#       Unnamed: 0                      Artist  \
# 0              0                     50 Cent
# 1              1                      Eminem
# 2              2                   Green Day
# 3              3                Mariah Carey
# 4              4              Kelly Clarkson
# 5              5                Gwen Stefani
# 6              6              Destinys Child
# 7              7                          U2
# 8              8                Shania Twain
# 9              9               Rascal Flatts
# 10            10                       Usher
# 11            11                  Toby Keith
# 12            12             Various Artists
# 13            13                    Coldplay
# 14            14                    Lil Jon
# 15            15                    The Game
# 16            16                 The Killers
# 17            17         The Black Eyed Peas
# 18            18                       Ciara
# 19            19                 Ray Charles
# 20            20                  Kanye West
# 21            21                    Ludacris
# 22            22             Gretchen Wilson
# 23            23             Various Artists
# 24            24                  Tim McGraw
# 25            25                    Fantasia
# 26            26                  Snoop Dogg
# 27            27                Jack Johnson
# 28            28                 Keith Urban
# 29            29               George Strait
# ...          ...                         ...
# 2339        2339              Dierks Bentley
# 2340        2340     Five Finger Death Punch
# 2352  I Can Only Imagine: The Very Best Of MercyMe  2018 -0.165894
# 2353                                          Aura  2018  0.475516
# 2354                                  Luca Brasi 3  2018  0.026743
# 2355                                       Ripcord  2018 -0.544421
# 2356                                        FUTURE  2018 -0.369641
# 2357                               Speak Your Mind  2018  0.265542
# 2358                          Reloaded: 20 #1 Hits  2018  0.854347
# 2359                      East Atlanta Love Letter  2018 -0.443858
# 2360                                 Back In Black  2018 -0.709274
# 2361                                      Thriller  2018  2.381295
# 2362                  Pretty Girls Like Trap Music  2018  0.187940
# 2363                                  Quavo Huncho  2018  0.388538
# 2364                                 Dancing Queen  2018 -0.799259
# 2365                                          Simi  2018 -0.418572
# 2366                                       Revenge  2018 -1.908563
# 2367                       Live In No Shoes Nation  2018  3.698097
# 2368                            Memories Don't Die  2018  0.564515
#
#       # of tracks
# 0        1.412699
# 1        1.611021
# 2       -1.165487
# 3       -0.173877
# 4       -0.570521
# 5       -0.570521
# 6       -0.768843
# 7       -0.768843
# 8        1.214377
# 9       -0.570521
# 10       1.214377
# 11      -0.173877
# 12       2.404309
# 13      -0.372199
# 14       0.817733
# 15       0.619411
# 16      -0.768843
# 17       0.024445
# 18      -0.372199
# 19      -0.570521
# 20       1.214377
# 21       0.222767
# 22      -0.967165
# 23       2.404309
# 24       0.222767
# 25      -0.372199
# 26       1.016055
# 27      -0.173877
# 28      -0.372199
# 29       6.965716
# ...           ...
# 2339    -0.372199
# 2340     0.222767
# 2341     2.007665
# 2342     0.222767
# 2343    -0.372199
# 2344     0.024445
# 2345     0.222767
# 2346     0.024445
# 2347     0.222767
# 2348    -0.768843
# 2349    -0.173877
# 2350     0.619411
# 2351    -0.768843
# 2352    -0.372199
# 2353     1.016055
# 2354     0.619411
# 2355    -0.372199
# 2356     0.222767
# 2357     0.619411
# 2358     1.214377
# 2359    -0.173877
# 2360    -0.967165
# 2361     2.999275
# 2362     0.222767
# 2363     0.817733
# 2364    -0.967165
# 2365     0.619411
# 2366    -1.562131
# 2367     2.800953
# 2368     0.619411
#
# [2369 rows x 6 columns]

# %%
sns.lineplot(x = 'Year', y = '# of tracks', data = normAlbum200, ci = None)
albumCtDur = sns.lineplot(x = 'Year', y = 'Duration', data = normAlbum200, ci = None)
albumCtDur.set(ylabel='')
albumCtDur.legend(labels = ['# of tracks', 'Duration'])
albumCtDur

# %%
normTop100 = top100.copy()
normTop100.rename(columns = {'Duration(min)':'Duration'}, inplace = True)

normTop100['Duration'] = ((top100['Duration(min)'] - top100['Duration(min)'].mean())/
                            (top100['Duration(min)'].std()))

# %%
sns.lineplot(x = 'Year', y = 'Duration', data = normAlbum200, ci = None)
albumsVsSingles = sns.lineplot(x = 'Year', y = 'Duration', data = normTop100, ci = None)
albumsVsSingles.set(ylabel = '')
albumsVsSingles.legend(labels = ['album duration', 'single duration'])
albumsVsSingles
