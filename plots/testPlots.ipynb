# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
top100 = pd.read_csv('songDataTop100ByYearfixtest.csv')

# %%
sns.lineplot(x = 'Year', y = 'Duration(ms)', data = top100)
plt.show()

# %%
sns.lineplot(x = 'Year', y = 'energy', data = top100)
plt.show()

# %%
sns.lineplot(x = 'Year', y = 'danceability', data = top100)
plt.show()

# %%
sns.lineplot(x = 'Year', y = 'speechiness', data = top100)
plt.show()

# %%
sns.lineplot(x = 'Year', y = 'loudness', data = top100)
plt.show()
