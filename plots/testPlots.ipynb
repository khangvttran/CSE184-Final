# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
top100 = pd.read_csv('songDataTop100ByYearfixtest.csv')
genre = pd.read_csv('genreData.csv')

# %%
sns.lineplot(x = 'Year', y = 'Duration(ms)', data = genre)
plt.show()

# %%
sns.lineplot(x = 'Year', y = 'energy', data = genre)
plt.show()

# %%
sns.lineplot(x = 'Year', y = 'danceability', data = genre)
plt.show()

# %%
sns.lineplot(x = 'Year', y = 'speechiness', data = genre)
plt.show()

# %%
sns.lineplot(x = 'Year', y = 'loudness', data = genre)
plt.show()
